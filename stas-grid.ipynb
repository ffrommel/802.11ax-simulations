# %%
# Constantes 
l = 9.8 # Largo de la sala (m)
a = 7.4 # Ancho de la sala (m)

# %%
from math import sqrt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# Calcular separación en largo y ancho de STAs
def separacion_l_a(stas):
    lado = sqrt((l*a) / stas) # lado del cuadrado de cada STA
    stas_l = round(l / lado)  # #STAs en largo
    stas_a = round(a / lado)  # #STAs en ancho 
    if stas_l * stas_a < stas:
        stas_a = stas_a + 1
    return l / stas_l, a / stas_a

# %%
# Obtener coordenadas
def coordenadas(stas):
    sep_l, sep_a = separacion_l_a(stas)
    print("sep largo: ", round(sep_l, 2), " - sep ancho: ", round(sep_a, 2))
    print("")
    i = sep_l / 2
    j = sep_a / 2
    cont = 1
    vect_x = []
    vect_y = []
    #print("Coordenadas:")
    while i < l:
        while j <= a:
            if cont <= stas:
                print("(" + str(round(i, 2)) + ",\t" + str(round(j, 2)) + ")")
                #print("(" + str(i) + ",\t" + str(j) + ")")
                #print("")
                vect_x.append(i)
                vect_y.append(j)
            j = j + sep_a
            cont = cont + 1
        i = i + sep_l
        j = sep_a / 2
    return vect_x, vect_y

# %%
# Graficar 1 grilla
sta = 12
vect_x, vect_y = coordenadas(sta)
plt.plot(vect_x, vect_y, 'o', color='black') # STAs
plt.plot(l / 2, a / 2, 'x', color='red') # AP
plt.xlim(0, l)
plt.ylim(0, a)
plt.title("#STAs " + str(sta))
# Out:
# sep largo:  2.45  - sep ancho:  2.47
#
# (1.23,	1.23)
# (1.23,	3.7)
# (1.23,	6.17)
# (3.68,	1.23)
# (3.68,	3.7)
# (3.68,	6.17)
# (6.12,	1.23)
# (6.12,	3.7)
# (6.12,	6.17)
# (8.57,	1.23)
# (8.57,	3.7)
# (8.57,	6.17)
# Text(0.5, 1.0, '#STAs 12')

# %%
# Graficar todas las grillas
vect_stas = [1] + [i for i in range(3, 54, 3)]
#vect_stas = [6, 12, 18, 24]
#print("#STAs a considerar:")
#print(vect_stas)
#print("")
vect_stas_it = iter(vect_stas)
cols = 4
rows = round(len(vect_stas) / cols) + 1
fig, axs = plt.subplots(rows, cols, figsize=(15, 15))
for i in range(0, rows):
    for j in range(0, cols):
        try:
            sta = next(vect_stas_it)
            print("")
            print("#STAs: ", sta)
        except:
            break
        vect_x, vect_y = coordenadas(sta)
        axs[i, j].plot(vect_x, vect_y, 'o', color='black') # STAs
        axs[i, j].plot(l / 2, a / 2, 'x', color='red') # AP
        axs[i, j].set_xlim(0, l)
        axs[i, j].set_ylim(0, a)
        axs[i, j].set_title("#STAs " + str(sta))
        axs[i, j].set_xlabel("Distance (m)")
        axs[i, j].set_ylabel("Distance (m)")
plt.tight_layout()
# Out:
# #STAs:  1
# sep largo:  9.8  - sep ancho:  7.4
#
# (4.9,	3.7)
#
# #STAs:  3
# sep largo:  4.9  - sep ancho:  3.7
#
# (2.45,	1.85)
# (2.45,	5.55)
# (7.35,	1.85)
#
# #STAs:  6
# sep largo:  3.27  - sep ancho:  3.7
#
# (1.63,	1.85)
# (1.63,	5.55)
# (4.9,	1.85)
# (4.9,	5.55)
# (8.17,	1.85)
# (8.17,	5.55)
#
# #STAs:  9
# sep largo:  3.27  - sep ancho:  2.47
#
# (1.63,	1.23)
# (1.63,	3.7)
# (1.63,	6.17)
# (4.9,	1.23)
# (4.9,	3.7)
# (4.9,	6.17)
# (8.17,	1.23)
# (8.17,	3.7)
# (8.17,	6.17)
#
# #STAs:  12
# sep largo:  2.45  - sep ancho:  2.47
#
# (1.23,	1.23)
# (1.23,	3.7)
# (1.23,	6.17)
# (3.68,	1.23)
# (3.68,	3.7)
# (3.68,	6.17)
# (6.12,	1.23)
# (6.12,	3.7)
# (6.12,	6.17)
# (8.57,	1.23)
# (8.57,	3.7)
# (8.57,	6.17)
#
# #STAs:  15
# sep largo:  2.45  - sep ancho:  1.85
#
# (1.23,	0.93)
# (1.23,	2.78)
# (1.23,	4.62)
# (1.23,	6.47)
# (3.68,	0.93)
# (3.68,	2.78)
# (3.68,	4.62)
# (3.68,	6.47)
# (6.12,	0.93)
# (6.12,	2.78)
# (6.12,	4.62)
# (6.12,	6.47)
# (8.57,	0.93)
# (8.57,	2.78)
# (8.57,	4.62)
#
# #STAs:  18
# sep largo:  1.96  - sep ancho:  1.85
#
# (0.98,	0.93)
# (0.98,	2.78)
# (0.98,	4.62)
# (0.98,	6.47)
# (2.94,	0.93)
# (2.94,	2.78)
# (2.94,	4.62)
# (2.94,	6.47)
# (4.9,	0.93)
# (4.9,	2.78)
# (4.9,	4.62)
# (4.9,	6.47)
# (6.86,	0.93)
# (6.86,	2.78)
# (6.86,	4.62)
# (6.86,	6.47)
# (8.82,	0.93)
# (8.82,	2.78)
#
# #STAs:  21
# sep largo:  1.96  - sep ancho:  1.48
#
# (0.98,	0.74)
# (0.98,	2.22)
# (0.98,	3.7)
# (0.98,	5.18)
# (0.98,	6.66)
# (2.94,	0.74)
# (2.94,	2.22)
# (2.94,	3.7)
# (2.94,	5.18)
# (2.94,	6.66)
# (4.9,	0.74)
# (4.9,	2.22)
# (4.9,	3.7)
# (4.9,	5.18)
# (4.9,	6.66)
# (6.86,	0.74)
# (6.86,	2.22)
# (6.86,	3.7)
# (6.86,	5.18)
# (6.86,	6.66)
# (8.82,	0.74)
#
# #STAs:  24
# sep largo:  1.63  - sep ancho:  1.85
#
# (0.82,	0.93)
# (0.82,	2.78)
# (0.82,	4.62)
# (0.82,	6.47)
# (2.45,	0.93)
# (2.45,	2.78)
# (2.45,	4.62)
# (2.45,	6.47)
# (4.08,	0.93)
# (4.08,	2.78)
# (4.08,	4.62)
# (4.08,	6.47)
# (5.72,	0.93)
# (5.72,	2.78)
# (5.72,	4.62)
# (5.72,	6.47)
# (7.35,	0.93)
# (7.35,	2.78)
# (7.35,	4.62)
# (7.35,	6.47)
# (8.98,	0.93)
# (8.98,	2.78)
# (8.98,	4.62)
# (8.98,	6.47)
#
# #STAs:  27
# sep largo:  1.63  - sep ancho:  1.48
#
# (0.82,	0.74)
# (0.82,	2.22)
# (0.82,	3.7)
# (0.82,	5.18)
# (0.82,	6.66)
# (2.45,	0.74)
# (2.45,	2.22)
# (2.45,	3.7)
# (2.45,	5.18)
# (2.45,	6.66)
# (4.08,	0.74)
# (4.08,	2.22)
# (4.08,	3.7)
# (4.08,	5.18)
# (4.08,	6.66)
# (5.72,	0.74)
# (5.72,	2.22)
# (5.72,	3.7)
# (5.72,	5.18)
# (5.72,	6.66)
# (7.35,	0.74)
# (7.35,	2.22)
# (7.35,	3.7)
# (7.35,	5.18)
# (7.35,	6.66)
# (8.98,	0.74)
# (8.98,	2.22)
#
# #STAs:  30
# sep largo:  1.63  - sep ancho:  1.48
#
# (0.82,	0.74)
# (0.82,	2.22)
# (0.82,	3.7)
# (0.82,	5.18)
# (0.82,	6.66)
# (2.45,	0.74)
# (2.45,	2.22)
# (2.45,	3.7)
# (2.45,	5.18)
# (2.45,	6.66)
# (4.08,	0.74)
# (4.08,	2.22)
# (4.08,	3.7)
# (4.08,	5.18)
# (4.08,	6.66)
# (5.72,	0.74)
# (5.72,	2.22)
# (5.72,	3.7)
# (5.72,	5.18)
# (5.72,	6.66)
# (7.35,	0.74)
# (7.35,	2.22)
# (7.35,	3.7)
# (7.35,	5.18)
# (7.35,	6.66)
# (8.98,	0.74)
# (8.98,	2.22)
# (8.98,	3.7)
# (8.98,	5.18)
# (8.98,	6.66)
#
# #STAs:  33
# sep largo:  1.4  - sep ancho:  1.48
#
# (0.7,	0.74)
# (0.7,	2.22)
# (0.7,	3.7)
# (0.7,	5.18)
# (0.7,	6.66)
# (2.1,	0.74)
# (2.1,	2.22)
# (2.1,	3.7)
# (2.1,	5.18)
# (2.1,	6.66)
# (3.5,	0.74)
# (3.5,	2.22)
# (3.5,	3.7)
# (3.5,	5.18)
# (3.5,	6.66)
# (4.9,	0.74)
# (4.9,	2.22)
# (4.9,	3.7)
# (4.9,	5.18)
# (4.9,	6.66)
# (6.3,	0.74)
# (6.3,	2.22)
# (6.3,	3.7)
# (6.3,	5.18)
# (6.3,	6.66)
# (7.7,	0.74)
# (7.7,	2.22)
# (7.7,	3.7)
# (7.7,	5.18)
# (7.7,	6.66)
# (9.1,	0.74)
# (9.1,	2.22)
# (9.1,	3.7)
#
# #STAs:  36
# sep largo:  1.4  - sep ancho:  1.23
#
# (0.7,	0.62)
# (0.7,	1.85)
# (0.7,	3.08)
# (0.7,	4.32)
# (0.7,	5.55)
# (0.7,	6.78)
# (2.1,	0.62)
# (2.1,	1.85)
# (2.1,	3.08)
# (2.1,	4.32)
# (2.1,	5.55)
# (2.1,	6.78)
# (3.5,	0.62)
# (3.5,	1.85)
# (3.5,	3.08)
# (3.5,	4.32)
# (3.5,	5.55)
# (3.5,	6.78)
# (4.9,	0.62)
# (4.9,	1.85)
# (4.9,	3.08)
# (4.9,	4.32)
# (4.9,	5.55)
# (4.9,	6.78)
# (6.3,	0.62)
# (6.3,	1.85)
# (6.3,	3.08)
# (6.3,	4.32)
# (6.3,	5.55)
# (6.3,	6.78)
# (7.7,	0.62)
# (7.7,	1.85)
# (7.7,	3.08)
# (7.7,	4.32)
# (7.7,	5.55)
# (7.7,	6.78)
#
# #STAs:  39
# sep largo:  1.4  - sep ancho:  1.23
#
# (0.7,	0.62)
# (0.7,	1.85)
# (0.7,	3.08)
# (0.7,	4.32)
# (0.7,	5.55)
# (0.7,	6.78)
# (2.1,	0.62)
# (2.1,	1.85)
# (2.1,	3.08)
# (2.1,	4.32)
# (2.1,	5.55)
# (2.1,	6.78)
# (3.5,	0.62)
# (3.5,	1.85)
# (3.5,	3.08)
# (3.5,	4.32)
# (3.5,	5.55)
# (3.5,	6.78)
# (4.9,	0.62)
# (4.9,	1.85)
# (4.9,	3.08)
# (4.9,	4.32)
# (4.9,	5.55)
# (4.9,	6.78)
# (6.3,	0.62)
# (6.3,	1.85)
# (6.3,	3.08)
# (6.3,	4.32)
# (6.3,	5.55)
# (6.3,	6.78)
# (7.7,	0.62)
# (7.7,	1.85)
# (7.7,	3.08)
# (7.7,	4.32)
# (7.7,	5.55)
# (7.7,	6.78)
# (9.1,	0.62)
# (9.1,	1.85)
# (9.1,	3.08)
#
# #STAs:  42
# sep largo:  1.4  - sep ancho:  1.23
#
# (0.7,	0.62)
# (0.7,	1.85)
# (0.7,	3.08)
# (0.7,	4.32)
# (0.7,	5.55)
# (0.7,	6.78)
# (2.1,	0.62)
# (2.1,	1.85)
# (2.1,	3.08)
# (2.1,	4.32)
# (2.1,	5.55)
# (2.1,	6.78)
# (3.5,	0.62)
# (3.5,	1.85)
# (3.5,	3.08)
# (3.5,	4.32)
# (3.5,	5.55)
# (3.5,	6.78)
# (4.9,	0.62)
# (4.9,	1.85)
# (4.9,	3.08)
# (4.9,	4.32)
# (4.9,	5.55)
# (4.9,	6.78)
# (6.3,	0.62)
# (6.3,	1.85)
# (6.3,	3.08)
# (6.3,	4.32)
# (6.3,	5.55)
# (6.3,	6.78)
# (7.7,	0.62)
# (7.7,	1.85)
# (7.7,	3.08)
# (7.7,	4.32)
# (7.7,	5.55)
# (7.7,	6.78)
# (9.1,	0.62)
# (9.1,	1.85)
# (9.1,	3.08)
# (9.1,	4.32)
# (9.1,	5.55)
# (9.1,	6.78)
#
# #STAs:  45
# sep largo:  1.23  - sep ancho:  1.23
#
# (0.61,	0.62)
# (0.61,	1.85)
# (0.61,	3.08)
# (0.61,	4.32)
# (0.61,	5.55)
# (0.61,	6.78)
# (1.84,	0.62)
# (1.84,	1.85)
# (1.84,	3.08)
# (1.84,	4.32)
# (1.84,	5.55)
# (1.84,	6.78)
# (3.06,	0.62)
# (3.06,	1.85)
# (3.06,	3.08)
# (3.06,	4.32)
# (3.06,	5.55)
# (3.06,	6.78)
# (4.29,	0.62)
# (4.29,	1.85)
# (4.29,	3.08)
# (4.29,	4.32)
# (4.29,	5.55)
# (4.29,	6.78)
# (5.51,	0.62)
# (5.51,	1.85)
# (5.51,	3.08)
# (5.51,	4.32)
# (5.51,	5.55)
# (5.51,	6.78)
# (6.74,	0.62)
# (6.74,	1.85)
# (6.74,	3.08)
# (6.74,	4.32)
# (6.74,	5.55)
# (6.74,	6.78)
# (7.96,	0.62)
# (7.96,	1.85)
# (7.96,	3.08)
# (7.96,	4.32)
# (7.96,	5.55)
# (7.96,	6.78)
# (9.19,	0.62)
# (9.19,	1.85)
# (9.19,	3.08)
#
# #STAs:  48
# sep largo:  1.23  - sep ancho:  1.23
#
# (0.61,	0.62)
# (0.61,	1.85)
# (0.61,	3.08)
# (0.61,	4.32)
# (0.61,	5.55)
# (0.61,	6.78)
# (1.84,	0.62)
# (1.84,	1.85)
# (1.84,	3.08)
# (1.84,	4.32)
# (1.84,	5.55)
# (1.84,	6.78)
# (3.06,	0.62)
# (3.06,	1.85)
# (3.06,	3.08)
# (3.06,	4.32)
# (3.06,	5.55)
# (3.06,	6.78)
# (4.29,	0.62)
# (4.29,	1.85)
# (4.29,	3.08)
# (4.29,	4.32)
# (4.29,	5.55)
# (4.29,	6.78)
# (5.51,	0.62)
# (5.51,	1.85)
# (5.51,	3.08)
# (5.51,	4.32)
# (5.51,	5.55)
# (5.51,	6.78)
# (6.74,	0.62)
# (6.74,	1.85)
# (6.74,	3.08)
# (6.74,	4.32)
# (6.74,	5.55)
# (6.74,	6.78)
# (7.96,	0.62)
# (7.96,	1.85)
# (7.96,	3.08)
# (7.96,	4.32)
# (7.96,	5.55)
# (7.96,	6.78)
# (9.19,	0.62)
# (9.19,	1.85)
# (9.19,	3.08)
# (9.19,	4.32)
# (9.19,	5.55)
# (9.19,	6.78)
#
# #STAs:  51
# sep largo:  1.23  - sep ancho:  1.06
#
# (0.61,	0.53)
# (0.61,	1.59)
# (0.61,	2.64)
# (0.61,	3.7)
# (0.61,	4.76)
# (0.61,	5.81)
# (0.61,	6.87)
# (1.84,	0.53)
# (1.84,	1.59)
# (1.84,	2.64)
# (1.84,	3.7)
# (1.84,	4.76)
# (1.84,	5.81)
# (1.84,	6.87)
# (3.06,	0.53)
# (3.06,	1.59)
# (3.06,	2.64)
# (3.06,	3.7)
# (3.06,	4.76)
# (3.06,	5.81)
# (3.06,	6.87)
# (4.29,	0.53)
# (4.29,	1.59)
# (4.29,	2.64)
# (4.29,	3.7)
# (4.29,	4.76)
# (4.29,	5.81)
# (4.29,	6.87)
# (5.51,	0.53)
# (5.51,	1.59)
# (5.51,	2.64)
# (5.51,	3.7)
# (5.51,	4.76)
# (5.51,	5.81)
# (5.51,	6.87)
# (6.74,	0.53)
# (6.74,	1.59)
# (6.74,	2.64)
# (6.74,	3.7)
# (6.74,	4.76)
# (6.74,	5.81)
# (6.74,	6.87)
# (7.96,	0.53)
# (7.96,	1.59)
# (7.96,	2.64)
# (7.96,	3.7)
# (7.96,	4.76)
# (7.96,	5.81)
# (7.96,	6.87)
# (9.19,	0.53)
# (9.19,	1.59)
